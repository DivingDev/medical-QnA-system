# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Supportiv/preprocessed.csv")
df.sample(10)
# Out:
#                                                 question  \
# 1960                       What is (are) Bone Diseases ?
# 7948   How to diagnose Parasites - Fascioliasis (Fasc...
# 9441             What is the outlook for Fabry Disease ?
# 3280                 What is (are) Chilaiditi syndrome ?
# 13242  How many people are affected by mevalonate kin...
# 9104   what research (or clinical trials) is being do...
# 3496          What are the symptoms of Sakati syndrome ?
# 6632   What are the treatments for X-linked hypophosp...
# 15142  How many people are affected by Tangier disease ?
# 1813                   What is (are) Colorectal Cancer ?
#
#                                                   answer  \
# 1960   Your bones help you move, give you shape and s...
# 7948   The standard way to be sure a person is infect...
# 9441   Individuals with Fabry disease often die prema...
# 3280   Chilaiditi syndrome is a medical condition in ...
# ...

# %%
df['text_to_train_fasttext'] = df['preprocessed_question'] + " " + df['preprocessed_answer']

# %%
df.to_csv("/content/drive/MyDrive/Supportiv/for_word_embedding.txt",columns = ['text_to_train_fasttext'], header = None, index = False)

# %%
# !pip install fasttext
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached pybind11-2.12.0-py3-none-any.whl (234 kB)
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4227138 sha256=3d6ef4f9296c826536c841e0052436285f06e8d1dea591594d9b13ae0c2fe0f2
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
# Successfully built fasttext
# ...

# %%
import fasttext
model = fasttext.train_unsupervised("/content/drive/MyDrive/Supportiv/for_word_embedding.txt",epoch = 10)

# %%
model.save_model("/content/drive/MyDrive/Supportiv/fasttext_model.bin")

# %%
model.get_nearest_neighbors("Glaucoma")
# Out:
# [(0.9559444189071655, 'glaucoma'),
#  (0.6285994052886963, 'chorioretinopathy'),
#  (0.6223006248474121, 'hyperopia'),
#  (0.6143879294395447, 'detachment'),
#  (0.6118220090866089, 'microcornea'),
#  (0.5931246280670166, 'cataract'),
#  (0.5807964205741882, 'sclerocornea'),
#  (0.5753979682922363, 'retinopathy'),
#  (0.5700501203536987, 'nearsightedness'),
#  (0.5661216378211975, 'opacification')]
